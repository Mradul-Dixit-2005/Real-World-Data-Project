# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    'Month': ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],
    'Sales': [12000,15000,18000,20000,22000,25000,27000,26000,24000,30000,35000,40000]
}

df = pd.DataFrame(data)

df
# Out:
#    Month  Sales
# 0    Jan  12000
# 1    Feb  15000
# 2    Mar  18000
# 3    Apr  20000
# 4    May  22000
# 5    Jun  25000
# 6    Jul  27000
# 7    Aug  26000
# 8    Sep  24000
# 9    Oct  30000
# 10   Nov  35000
# 11   Dec  40000

# %%
print("Dataset Shape:", df.shape)

print("\nSummary Statistics:")
print(df.describe())
# Out:
# Dataset Shape: (12, 2)
#
# Summary Statistics:
#               Sales
# count     12.000000
# mean   24500.000000
# std     8005.679802
# min    12000.000000
# 25%    19500.000000
# 50%    24500.000000
# 75%    27750.000000
# max    40000.000000

# %% [markdown]
# plt.figure(figsize=(10,5))
#
# plt.plot(
#     df['Month'],
#     df['Sales'],
#     marker='o'
# )
#
# plt.title("Monthly Sales Trend")
# plt.xlabel("Month")
# plt.ylabel("Sales")
#
# plt.grid(True)
#
# plt.show()

# %%
highest = df.loc[df['Sales'].idxmax()]

print("Highest Sales Month:")
print(highest)
# Out:
# Highest Sales Month:
# Month      Dec
# Sales    40000
# Name: 11, dtype: object

# %%
plt.figure(figsize=(10,5))

plt.bar(
    df['Month'],
    df['Sales']
)

plt.title("Monthly Sales Comparison")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.show()

# %%
print("""
Project Findings

1. Sales steadily increased throughout the year.
2. November and December recorded the highest sales.
3. December achieved maximum sales.
4. Overall business growth trend is positive.
5. Seasonal demand appears strongest during year-end months.
""")
# Out:
# Project Findings
#
# 1. Sales steadily increased throughout the year.
# 2. November and December recorded the highest sales.
# 3. December achieved maximum sales.
# 4. Overall business growth trend is positive.
# 5. Seasonal demand appears strongest during year-end months.
